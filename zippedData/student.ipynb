# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %%
# Your code here - remember to use markdown cells for comments as well!

import pandas as pd
import os

# %%
variable = pd.read_csv(r"C:\Users\somep\Documents\Flatiron\dsc-phase-1-project-v2-4\zippedData\bom.movie_gross.csv.gz")
variable.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
variable = pd.read_csv(r"C:\Users\somep\Documents\Flatiron\dsc-phase-1-project-v2-4\zippedData\tmdb.movies.csv.gz")
variable.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# ...

# %%
variable = pd.read_csv(r"C:\Users\somep\Documents\Flatiron\dsc-phase-1-project-v2-4\zippedData\tn.movie_budgets.csv.gz")
variable.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
data=pd.read_table(r"C:\Users\somep\Documents\Flatiron\dsc-phase-1-project-v2-4\zippedData\rt.movie_info.tsv.gz")
data.head()
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# ...

# %%
data=pd.read_table(r"C:\Users\somep\Documents\Flatiron\dsc-phase-1-project-v2-4\zippedData\rt.reviews.tsv.gz")
data
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_332\1902765872.py in <module>
# ----> 1 data=pd.read_table(r"C:\Users\somep\Documents\Flatiron\dsc-phase-1-project-v2-4\zippedData\rt.reviews.tsv.gz")
#       2 data
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
import pandas as pd
import numpy as np
import sqlite3 as sql

# %%
con = sql.connect(r"C:\Users\somep\Documents\Flatiron\dsc-phase-1-project-v2-4\zippedData\im.db\im.db")

# %%
database = "im.db"
connection = sql.connect(database)

# %%
query = '''SELECT * FROM im.db'''

# %%
schema_df = pd.read_sql("""

SELECT *
FROM sqlite_master

""", con)

schema_df
# Out:
#     type           name       tbl_name  rootpage  \
# 0  table   movie_basics   movie_basics         2
# 1  table      directors      directors         3
# 2  table      known_for      known_for         4
# 3  table     movie_akas     movie_akas         5
# 4  table  movie_ratings  movie_ratings         6
# 5  table        persons        persons         7
# 6  table     principals     principals         8
# 7  table        writers        writers         9
#
#                                                  sql
# 0  CREATE TABLE "movie_basics" (\n"movie_id" TEXT...
# 1  CREATE TABLE "directors" (\n"movie_id" TEXT,\n...
# 2  CREATE TABLE "known_for" (\n"person_id" TEXT,\...
# 3  CREATE TABLE "movie_akas" (\n"movie_id" TEXT,\...
# 4  CREATE TABLE "movie_ratings" (\n"movie_id" TEX...
# 5  CREATE TABLE "persons" (\n"person_id" TEXT,\n ...
# 6  CREATE TABLE "principals" (\n"movie_id" TEXT,\...
# 7  CREATE TABLE "writers" (\n"movie_id" TEXT,\n  ...

# %%
print(schema_df['sql'].iloc[0])
# Out:
# CREATE TABLE "movie_basics" (
# "movie_id" TEXT,
#   "primary_title" TEXT,
#   "original_title" TEXT,
#   "start_year" INTEGER,
#   "runtime_minutes" REAL,
#   "genres" TEXT
# )

# %%
#import sqlite3
#conn = sqlite3.connect('im.db')
#c = conn.cursor()

#c.execute("""create table emp(movie_basics,directors,known_for,movie_akas,movie_ratings,persons,principals,writers)""")

#conn.commit()

# %%
movie_basics_df = pd.read_sql("""

SELECT *
FROM movie_basics

""", con)

movie_basics_df.head()
# Out:
#     movie_id                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
directors_df = pd.read_sql("""

SELECT *
FROM directors

""", con)

directors_df.head()
# Out:
#     movie_id  person_id
# 0  tt0285252  nm0899854
# 1  tt0462036  nm1940585
# 2  tt0835418  nm0151540
# 3  tt0835418  nm0151540
# 4  tt0878654  nm0089502

# %%
known_for_df = pd.read_sql("""

SELECT *
FROM known_for

""", con)

known_for_df.head()
# Out:
#    person_id   movie_id
# 0  nm0061671  tt0837562
# 1  nm0061671  tt2398241
# 2  nm0061671  tt0844471
# 3  nm0061671  tt0118553
# 4  nm0061865  tt0896534

# %%
movie_akas_df = pd.read_sql("""

SELECT *
FROM movie_akas

""", con)

movie_akas_df.head()
# Out:
#     movie_id  ordering                                    title region  \
# 0  tt0369610        10                            Джурасик свят     BG
# 1  tt0369610        11                        Jurashikku warudo     JP
# 2  tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3  tt0369610        13                  O Mundo dos Dinossauros     BR
# 4  tt0369610        14                           Jurassic World     FR
#
#   language        types   attributes  is_original_title
# 0       bg         None         None                0.0
# 1     None  imdbDisplay         None                0.0
# 2     None  imdbDisplay         None                0.0
# 3     None         None  short title                0.0
# 4     None  imdbDisplay         None                0.0

# %%
movie_ratings_df = pd.read_sql("""

SELECT *
FROM movie_ratings

""", con)

movie_ratings_df.head()
# Out:
#      movie_id  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
persons_df = pd.read_sql("""

SELECT *
FROM persons

""", con)

persons_df.head()
# Out:
#    person_id       primary_name  birth_year  death_year  \
# 0  nm0061671  Mary Ellen Bauder         NaN         NaN
# 1  nm0061865       Joseph Bauer         NaN         NaN
# 2  nm0062070         Bruce Baum         NaN         NaN
# 3  nm0062195       Axel Baumann         NaN         NaN
# 4  nm0062798        Pete Baxter         NaN         NaN
#
#                                  primary_profession
# 0         miscellaneous,production_manager,producer
# 1        composer,music_department,sound_department
# 2                        miscellaneous,actor,writer
# 3  camera_department,cinematographer,art_department
# 4  production_designer,art_department,set_decorator

# %%
principals_df = pd.read_sql("""

SELECT *
FROM principals

""", con)

principals_df.head()
# Out:
#     movie_id  ordering  person_id  category       job        characters
# 0  tt0111414         1  nm0246005     actor      None       ["The Man"]
# 1  tt0111414         2  nm0398271  director      None              None
# 2  tt0111414         3  nm3739909  producer  producer              None
# 3  tt0323808        10  nm0059247    editor      None              None
# 4  tt0323808         1  nm3579312   actress      None  ["Beth Boothby"]

# %%
writers_df = pd.read_sql("""

SELECT *
FROM writers

""", con)

writers_df.head()
# Out:
#     movie_id  person_id
# 0  tt0285252  nm0899854
# 1  tt0438973  nm0175726
# 2  tt0438973  nm1802864
# 3  tt0462036  nm1940585
# 4  tt0835418  nm0310087

# %%
movie_basics_directors = pd.merge(movie_basics_df, directors_df)
movie_basics_directors.columns
# Out:
# Index(['movie_id', 'primary_title', 'original_title', 'start_year',
#        'runtime_minutes', 'genres', 'person_id'],
#       dtype='object')

# %%
movie_basics_directors.head()
# Out:
#     movie_id                    primary_title   original_title  start_year  \
# 0  tt0063540                        Sunghursh        Sunghursh        2013
# 1  tt0063540                        Sunghursh        Sunghursh        2013
# 2  tt0063540                        Sunghursh        Sunghursh        2013
# 3  tt0063540                        Sunghursh        Sunghursh        2013
# 4  tt0066787  One Day Before the Rainy Season  Ashad Ka Ek Din        2019
#
#    runtime_minutes              genres  person_id
# 0            175.0  Action,Crime,Drama  nm0712540
# 1            175.0  Action,Crime,Drama  nm0712540
# 2            175.0  Action,Crime,Drama  nm0712540
# 3            175.0  Action,Crime,Drama  nm0712540
# 4            114.0     Biography,Drama  nm0002411

# %%
MOVIEDIRECTORSRATINGS = pd.merge(movie_basics_directors, movie_ratings_df)
MOVIEDIRECTORSRATINGS.columns
# Out:
# Index(['movie_id', 'primary_title', 'original_title', 'start_year',
#        'runtime_minutes', 'genres', 'person_id', 'averagerating', 'numvotes'],
#       dtype='object')

# %%
MOVIEDIRECTORSRATINGS.head()
# Out:
#     movie_id                    primary_title   original_title  start_year  \
# 0  tt0063540                        Sunghursh        Sunghursh        2013
# 1  tt0063540                        Sunghursh        Sunghursh        2013
# 2  tt0063540                        Sunghursh        Sunghursh        2013
# 3  tt0063540                        Sunghursh        Sunghursh        2013
# 4  tt0066787  One Day Before the Rainy Season  Ashad Ka Ek Din        2019
#
#    runtime_minutes              genres  person_id  averagerating  numvotes
# 0            175.0  Action,Crime,Drama  nm0712540            7.0        77
# 1            175.0  Action,Crime,Drama  nm0712540            7.0        77
# 2            175.0  Action,Crime,Drama  nm0712540            7.0        77
# 3            175.0  Action,Crime,Drama  nm0712540            7.0        77
# 4            114.0     Biography,Drama  nm0002411            7.2        43

# %%
MOVIEDIRECTORSRATINGS2 = pd.merge(MOVIEDIRECTORSRATINGS, known_for_df)
MOVIEDIRECTORSRATINGS2.columns
# Out:
# Index(['movie_id', 'primary_title', 'original_title', 'start_year',
#        'runtime_minutes', 'genres', 'person_id', 'averagerating', 'numvotes'],
#       dtype='object')

# %%
MOVIEDIRECTORSRATINGS2.head()
# Out:
#     movie_id             primary_title         original_title  start_year  \
# 0  tt0100275  The Wandering Soap Opera  La Telenovela Errante        2017
# 1  tt0100275  The Wandering Soap Opera  La Telenovela Errante        2017
# 2  tt0100275  The Wandering Soap Opera  La Telenovela Errante        2017
# 3  tt0100275  The Wandering Soap Opera  La Telenovela Errante        2017
# 4  tt0112502                   Bigfoot                Bigfoot        2017
#
#    runtime_minutes                genres  person_id  averagerating  numvotes
# 0             80.0  Comedy,Drama,Fantasy  nm0765384            6.5       119
# 1             80.0  Comedy,Drama,Fantasy  nm0765384            6.5       119
# 2             80.0  Comedy,Drama,Fantasy  nm0749914            6.5       119
# 3             80.0  Comedy,Drama,Fantasy  nm0749914            6.5       119
# 4              NaN       Horror,Thriller  nm6883878            4.1        32

# %%
MOVIEDIRECTORSRATINGS3 = pd.merge(MOVIEDIRECTORSRATINGS2, movie_akas_df)
MOVIEDIRECTORSRATINGS3.columns
# Out:
# Index(['movie_id', 'primary_title', 'original_title', 'start_year',
#        'runtime_minutes', 'genres', 'person_id', 'averagerating', 'numvotes',
#        'ordering', 'title', 'region', 'language', 'types', 'attributes',
#        'is_original_title'],
#       dtype='object')

# %%
MOVIEDIRECTORSRATINGS3.head()
# Out:
#     movie_id             primary_title         original_title  start_year  \
# 0  tt0100275  The Wandering Soap Opera  La Telenovela Errante        2017
# 1  tt0100275  The Wandering Soap Opera  La Telenovela Errante        2017
# 2  tt0100275  The Wandering Soap Opera  La Telenovela Errante        2017
# 3  tt0100275  The Wandering Soap Opera  La Telenovela Errante        2017
# 4  tt0100275  The Wandering Soap Opera  La Telenovela Errante        2017
#
#    runtime_minutes                genres  person_id  averagerating  numvotes  \
# 0             80.0  Comedy,Drama,Fantasy  nm0765384            6.5       119
# 1             80.0  Comedy,Drama,Fantasy  nm0765384            6.5       119
# 2             80.0  Comedy,Drama,Fantasy  nm0765384            6.5       119
# 3             80.0  Comedy,Drama,Fantasy  nm0765384            6.5       119
# 4             80.0  Comedy,Drama,Fantasy  nm0765384            6.5       119
#
# ...

# %%
MOVIEDIRECTORSRATINGS4 = pd.merge(MOVIEDIRECTORSRATINGS3, persons_df)
MOVIEDIRECTORSRATINGS4.columns
# Out:
# Index(['movie_id', 'primary_title', 'original_title', 'start_year',
#        'runtime_minutes', 'genres', 'person_id', 'averagerating', 'numvotes',
#        'ordering', 'title', 'region', 'language', 'types', 'attributes',
#        'is_original_title', 'primary_name', 'birth_year', 'death_year',
#        'primary_profession'],
#       dtype='object')

# %%
MOVIEDIRECTORSRATINGS4.head()
# Out:
#     movie_id             primary_title         original_title  start_year  \
# 0  tt0100275  The Wandering Soap Opera  La Telenovela Errante        2017
# 1  tt0100275  The Wandering Soap Opera  La Telenovela Errante        2017
# 2  tt0100275  The Wandering Soap Opera  La Telenovela Errante        2017
# 3  tt0100275  The Wandering Soap Opera  La Telenovela Errante        2017
# 4  tt0100275  The Wandering Soap Opera  La Telenovela Errante        2017
#
#    runtime_minutes                genres  person_id  averagerating  numvotes  \
# 0             80.0  Comedy,Drama,Fantasy  nm0765384            6.5       119
# 1             80.0  Comedy,Drama,Fantasy  nm0765384            6.5       119
# 2             80.0  Comedy,Drama,Fantasy  nm0765384            6.5       119
# 3             80.0  Comedy,Drama,Fantasy  nm0765384            6.5       119
# 4             80.0  Comedy,Drama,Fantasy  nm0765384            6.5       119
#
# ...

# %%
MOVIEDIRECTORSRATINGS5 = pd.merge(MOVIEDIRECTORSRATINGS4, principals_df)
MOVIEDIRECTORSRATINGS5.columns
# Out:
# Index(['movie_id', 'primary_title', 'original_title', 'start_year',
#        'runtime_minutes', 'genres', 'person_id', 'averagerating', 'numvotes',
#        'ordering', 'title', 'region', 'language', 'types', 'attributes',
#        'is_original_title', 'primary_name', 'birth_year', 'death_year',
#        'primary_profession', 'category', 'job', 'characters'],
#       dtype='object')

# %%
MOVIEDIRECTORSRATINGS5.head()
# Out:
#     movie_id             primary_title         original_title  start_year  \
# 0  tt1928329       Lines of Wellington   Linhas de Wellington        2012
# 1  tt0100275  The Wandering Soap Opera  La Telenovela Errante        2017
# 2  tt0100275  The Wandering Soap Opera  La Telenovela Errante        2017
# 3  tt1236371       Mysteries of Lisbon    Mistérios de Lisboa        2010
# 4  tt1236371       Mysteries of Lisbon    Mistérios de Lisboa        2010
#
#    runtime_minutes                 genres  person_id  averagerating  numvotes  \
# 0            151.0      Drama,History,War  nm0765384            6.2      1235
# 1             80.0   Comedy,Drama,Fantasy  nm0749914            6.5       119
# 2             80.0   Comedy,Drama,Fantasy  nm0749914            6.5       119
# 3            272.0  Drama,Mystery,Romance  nm0749914            7.5      2928
# 4            272.0  Drama,Mystery,Romance  nm0749914            7.5      2928
#
# ...

# %%
MOVIEDIRECTORSRATINGS6 = pd.merge(MOVIEDIRECTORSRATINGS5, writers_df)
MOVIEDIRECTORSRATINGS6.columns
# Out:
# Index(['movie_id', 'primary_title', 'original_title', 'start_year',
#        'runtime_minutes', 'genres', 'person_id', 'averagerating', 'numvotes',
#        'ordering', 'title', 'region', 'language', 'types', 'attributes',
#        'is_original_title', 'primary_name', 'birth_year', 'death_year',
#        'primary_profession', 'category', 'job', 'characters'],
#       dtype='object')

# %%
MOVIEDIRECTORSRATINGS6.head()
# Out:
#     movie_id             primary_title         original_title  start_year  \
# 0  tt0100275  The Wandering Soap Opera  La Telenovela Errante        2017
# 1  tt0100275  The Wandering Soap Opera  La Telenovela Errante        2017
# 2  tt0100275  The Wandering Soap Opera  La Telenovela Errante        2017
# 3  tt0100275  The Wandering Soap Opera  La Telenovela Errante        2017
# 4  tt0137204           Joe Finds Grace        Joe Finds Grace        2017
#
#    runtime_minutes                      genres  person_id  averagerating  \
# 0             80.0        Comedy,Drama,Fantasy  nm0749914            6.5
# 1             80.0        Comedy,Drama,Fantasy  nm0749914            6.5
# 2             80.0        Comedy,Drama,Fantasy  nm0749914            6.5
# 3             80.0        Comedy,Drama,Fantasy  nm0749914            6.5
# 4             83.0  Adventure,Animation,Comedy  nm0365480            8.1
#
#    numvotes  ordering  ...        types attributes is_original_title  \
# ...

# %%
variable1 = pd.read_csv(r"C:\Users\somep\Documents\Flatiron\dsc-phase-1-project-v2-4\zippedData\bom.movie_gross.csv.gz")
variable1.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
MOVIEDIRECTORSRATINGS7 = pd.merge(MOVIEDIRECTORSRATINGS6, variable1)
MOVIEDIRECTORSRATINGS7.columns
# Out:
# Index(['movie_id', 'primary_title', 'original_title', 'start_year',
#        'runtime_minutes', 'genres', 'person_id', 'averagerating', 'numvotes',
#        'ordering', 'title', 'region', 'language', 'types', 'attributes',
#        'is_original_title', 'primary_name', 'birth_year', 'death_year',
#        'primary_profession', 'category', 'job', 'characters', 'studio',
#        'domestic_gross', 'foreign_gross', 'year'],
#       dtype='object')

# %%
MOVIEDIRECTORSRATINGS7.head()
# Out:
#     movie_id primary_title original_title  start_year  runtime_minutes  \
# 0  tt3906082  Mary Shelley   Mary Shelley        2017            120.0
# 1  tt3906082  Mary Shelley   Mary Shelley        2017            120.0
# 2  tt0409379     In Secret      In Secret        2013            107.0
# 3  tt0409379     In Secret      In Secret        2013            107.0
# 4  tt0409379     In Secret      In Secret        2013            107.0
#
#                     genres  person_id  averagerating  numvotes  ordering  ...  \
# 0  Biography,Drama,History  nm2223783            6.4      8534         5  ...
# 1  Biography,Drama,History  nm2223783            6.4      8534         5  ...
# 2     Crime,Drama,Thriller  nm0833627            6.2      7045         5  ...
# 3     Crime,Drama,Thriller  nm0833627            6.2      7045         5  ...
# 4     Crime,Drama,Thriller  nm0833627            6.2      7045         5  ...
#
# ...

# %%
variable2 = pd.read_csv(r"C:\Users\somep\Documents\Flatiron\dsc-phase-1-project-v2-4\zippedData\tmdb.movies.csv.gz")
variable2.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# ...

# %%
MOVIEDIRECTORSRATINGS8 = pd.merge(MOVIEDIRECTORSRATINGS7, variable2)
MOVIEDIRECTORSRATINGS8.columns
# Out:
# Index(['movie_id', 'primary_title', 'original_title', 'start_year',
#        'runtime_minutes', 'genres', 'person_id', 'averagerating', 'numvotes',
#        'ordering', 'title', 'region', 'language', 'types', 'attributes',
#        'is_original_title', 'primary_name', 'birth_year', 'death_year',
#        'primary_profession', 'category', 'job', 'characters', 'studio',
#        'domestic_gross', 'foreign_gross', 'year', 'Unnamed: 0', 'genre_ids',
#        'id', 'original_language', 'popularity', 'release_date', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
MOVIEDIRECTORSRATINGS8.head()
# Out:
#     movie_id primary_title original_title  start_year  runtime_minutes  \
# 0  tt3906082  Mary Shelley   Mary Shelley        2017            120.0
# 1  tt3906082  Mary Shelley   Mary Shelley        2017            120.0
# 2  tt0409379     In Secret      In Secret        2013            107.0
# 3  tt0409379     In Secret      In Secret        2013            107.0
# 4  tt0409379     In Secret      In Secret        2013            107.0
#
#                     genres  person_id  averagerating  numvotes  ordering  ...  \
# 0  Biography,Drama,History  nm2223783            6.4      8534         5  ...
# 1  Biography,Drama,History  nm2223783            6.4      8534         5  ...
# 2     Crime,Drama,Thriller  nm0833627            6.2      7045         5  ...
# 3     Crime,Drama,Thriller  nm0833627            6.2      7045         5  ...
# 4     Crime,Drama,Thriller  nm0833627            6.2      7045         5  ...
#
# ...

# %%
variable3 = pd.read_csv(r"C:\Users\somep\Documents\Flatiron\dsc-phase-1-project-v2-4\zippedData\tn.movie_budgets.csv.gz")
variable3.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
to_concat = [variable3, MOVIEDIRECTORSRATINGS8]
big_df = pd.concat(to_concat)

# %%
big_df.columns
# Out:
# Index(['id', 'release_date', 'movie', 'production_budget', 'domestic_gross',
#        'worldwide_gross', 'movie_id', 'primary_title', 'original_title',
#        'start_year', 'runtime_minutes', 'genres', 'person_id', 'averagerating',
#        'numvotes', 'ordering', 'title', 'region', 'language', 'types',
#        'attributes', 'is_original_title', 'primary_name', 'birth_year',
#        'death_year', 'primary_profession', 'category', 'job', 'characters',
#        'studio', 'foreign_gross', 'year', 'Unnamed: 0', 'genre_ids',
#        'original_language', 'popularity', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
big_df.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross movie_id primary_title  \
# 0      $425,000,000   $760,507,625  $2,776,345,279      NaN           NaN
# 1      $410,600,000   $241,063,875  $1,045,663,875      NaN           NaN
# 2      $350,000,000    $42,762,350    $149,762,350      NaN           NaN
# 3      $330,600,000   $459,005,868  $1,403,013,963      NaN           NaN
# 4      $317,000,000   $620,181,382  $1,316,721,747      NaN           NaN
#
#   original_title  start_year  ...  characters studio foreign_gross  year  \
# ...

# %%
big_df.drop(['movie_id', 'primary_title', 'original_title', 'start_year', 'category', 'job', 'characters', 'person_id', 'Unnamed: 0', 'genre_ids', 'birth_year', 'death_year', 'is_original_title', 'attributes', 'types', 'language', 'primary_name', 'primary_profession'], axis = 1)
# Out:
#          id  release_date                                        movie  \
# 0         1  Dec 18, 2009                                       Avatar
# 1         2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2         3   Jun 7, 2019                                 Dark Phoenix
# 3         4   May 1, 2015                      Avengers: Age of Ultron
# 4         5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ..      ...           ...                                          ...
# 732  460668    2018-04-20                                          NaN
# 733   44826    2011-11-23                                          NaN
# 734   44826    2011-11-23                                          NaN
# 735  210522    2012-07-07                                          NaN
# 736  118289    2013-11-01                                          NaN
#
#     production_budget domestic_gross worldwide_gross  runtime_minutes  \
# ...

# %%
import pip
pip.main(["install", "openpyxl"])
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# ...
# 0

# %%
import pandas as pd
import openpyxl as xls

# %%
big_df.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross movie_id primary_title  \
# 0      $425,000,000   $760,507,625  $2,776,345,279      NaN           NaN
# 1      $410,600,000   $241,063,875  $1,045,663,875      NaN           NaN
# 2      $350,000,000    $42,762,350    $149,762,350      NaN           NaN
# 3      $330,600,000   $459,005,868  $1,403,013,963      NaN           NaN
# 4      $317,000,000   $620,181,382  $1,316,721,747      NaN           NaN
#
#   original_title  start_year  ...  characters studio foreign_gross  year  \
# ...

# %%
excel_file = pd.ExcelWriter("big_df_file.xlsx")

# %%
big_df.to_excel(excel_file)

# %%
excel_file.save()

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\somep\Documents\Flatiron\dsc-phase-1-project-v2-4\zippedData\renamed_file.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_332\3595523707.py in <module>
# ----> 1 df = pd.read_csv(r"C:\Users\somep\Documents\Flatiron\dsc-phase-1-project-v2-4\zippedData\renamed_file.csv")
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df = pd.read_csv(r"C:\Users\somep\Documents\Flatiron\dsc-phase-1-project-v2-4\zippedData\renamed_file.csv",encoding='latin-1')

# %%
df
# Out:
#         id release_date                                        movie  \
# 0        1    18-Dec-09                                       Avatar
# 1        2    20-May-11  Pirates of the Caribbean: On Stranger Tides
# 2        3     7-Jun-19                                 Dark Phoenix
# 3        4     1-May-15                      Avengers: Age of Ultron
# 4        5    15-Dec-17            Star Wars Ep. VIII: The Last Jedi
# ...    ...          ...                                          ...
# 5967  6502    10-Jun-17                       Earth: One Amazing Day
# 5968  6511    18-Aug-17                                  Patti Cakes
# 5969  6512    20-Apr-18                                I Feel Pretty
# 5970  6516    23-Nov-11                                         Hugo
# 5971  6518     7-Jul-12                                        Diana
#
#       production_budget  domestic_gross  worldwide_gross  runtime  \
# 0           425000000.0     760507625.0     2.776345e+09      NaN
# ...

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats
from sklearn.datasets import load_iris

# %%
domestic = pd.read_csv(r"C:\Users\somep\Documents\Flatiron\dsc-phase-1-project-v2-4\zippedData\Highest_Grossing_Domestic.csv",encoding='latin-1')

# %%
domestic
# Out:
#       id release_date                                          movie  \
# 0      6    18-Dec-15           Star Wars Ep. VII: The Force Awakens
# 1      1    18-Dec-09                                         Avatar
# 2     42    16-Feb-18                                  Black Panther
# 3      7    27-Apr-18                         Avengers: Infinity War
# 4     43    19-Dec-97                                        Titanic
# 5     34    12-Jun-15                                 Jurassic World
# 6     27     4-May-12                                   The Avengers
# 7      5    15-Dec-17              Star Wars Ep. VIII: The Last Jedi
# 8     44    15-Jun-18                                  Incredibles 2
# 9     75    18-Jul-08                                The Dark Knight
# 10    45    16-Dec-16                   Rogue One: A Star Wars Story
# 11   135    17-Mar-17                           Beauty and the Beast
# 12    46    17-Jun-16                                   Finding Dory
# ...

# %%
myFreq = domestic['domestic_gross'].value_counts()
myFreq
# Out:
# 936662225    1
# 381193157    1
# 408992272    1
# 408084349    1
# 408010692    1
# 404508916    1
# 403706375    1
# 402111870    1
# 400738009    1
# 395708305    1
# 389813101    1
# 380529370    1
# 415004880    1
# 380270577    1
# 377845905    1
# 376057266    1
# 373524485    1
# 370782930    1
# 368384330    1
# 368065385    1
# 364001123    1
# 363070709    1
# 412563408    1
# 417719760    1
# 760507625    1
# 504014165    1
# 700059566    1
# 678815482    1
# 659363944    1
# 652270625    1
# 623279547    1
# 620181382    1
# 608581744    1
# 533720947    1
# 532177324    1
# 486295561    1
# 421785283    1
# 474544677    1
# 460998007    1
# 459005868    1
# 448139099    1
# 441226247    1
# 435110554    1
# 426525952    1
# 424668047    1
# 423315812    1
# 356461711    1
# Name: domestic_gross, dtype: int64

# %%
genrebreakdown = pd.read_csv(r"C:\Users\somep\Documents\Flatiron\dsc-phase-1-project-v2-4\zippedData\Genre_Breakdown.csv",encoding='latin-1')

# %%
genrebreakdown
# Out:
#      Code       Date                   Title  Unnamed: 3  Domestic Gross  \
# 0    5783  25-May-18            Mary Shelley         NaN        109000.0
# 1    5785  21-Feb-14               In Secret         NaN        444000.0
# 2    5788  21-Apr-17               Free Fire         NaN       1800000.0
# 3    5790  30-Sep-11                Margaret         NaN         46500.0
# 4    5791  22-Aug-12                 Samsara         NaN       2700000.0
# ..    ...        ...                     ...         ...             ...
# 185  6502  10-Jun-17  Earth: One Amazing Day         NaN         81300.0
# 186  6511  18-Aug-17             Patti Cakes         NaN        800000.0
# 187  6512  20-Apr-18           I Feel Pretty         NaN      48800000.0
# 188  6516  23-Nov-11                    Hugo         NaN      73900000.0
# 189  6518   7-Jul-12                   Diana         NaN        335000.0
#
#      Unnamed: 5  Runtime                    Genre
# ...

# %%
myFreq = genrebreakdown['Genre'].value_counts()
myFreq
# Out:
# Drama                     23
# Documentary               15
# Comedy,Drama              11
# Comedy,Drama,Romance       9
# Crime,Drama,Thriller       6
#                           ..
# Adventure,Drama            1
# Comedy,Crime,Thriller      1
# Drama,Fantasy,Mystery      1
# Action,Fantasy,Western     1
# Mystery                    1
# Name: Genre, Length: 80, dtype: int64

# %%
myFreq.plot(kind='bar')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
MostExpensive = pd.read_csv(r"C:\Users\somep\Documents\Flatiron\dsc-phase-1-project-v2-4\zippedData\SimpleFiles.csv",encoding='latin-1')

# %%
MostExpensive[0:10]
# Out:
#    id release_date                                        movie  \
# 0   1    18-Dec-09                                       Avatar
# 1   2    20-May-11  Pirates of the Caribbean: On Stranger Tides
# 2   3     7-Jun-19                                 Dark Phoenix
# 3   4     1-May-15                      Avengers: Age of Ultron
# 4   5    15-Dec-17            Star Wars Ep. VIII: The Last Jedi
# 5   6    18-Dec-15         Star Wars Ep. VII: The Force Awakens
# 6   7    27-Apr-18                       Avengers: Infinity War
# 7   8    24-May-07   Pirates of the Caribbean: At Worldâs End
# 8   9    17-Nov-17                               Justice League
# 9  10     6-Nov-15                                      Spectre
#
#    production_budget  domestic_gross  worldwide_gross      Net gain
# 0        425000000.0     760507625.0     2.776345e+09  2.351345e+09
# 1        410600000.0     241063875.0     1.045664e+09  6.350639e+08
# ...

# %%
df = MostExpensive["production_budget"]

# %%
budgetplot = df.plot(kind="bar"[0:10])

# %%
df1 = pd.read_csv(r"C:\Users\somep\Documents\Flatiron\dsc-phase-1-project-v2-4\zippedData\ProductionBudget.csv",encoding='latin-1')

# %%
budget = df1["production_budget"]

# %%
budgetplot = budget.plot(kind="bar")

# %%
df2 = pd.read_csv(r"C:\Users\somep\Documents\Flatiron\dsc-phase-1-project-v2-4\zippedData\Highest Grossing Movies of All Time Domestic.csv",encoding='latin-1')

# %%
domesticgross = df2["domestic_gross"]

# %%
domesticplot = domesticgross.plot(kind="bar")

# %%
df3 = pd.read_csv(r"C:\Users\somep\Documents\Flatiron\dsc-phase-1-project-v2-4\zippedData\Least Profitable.csv",encoding='latin-1')

# %%
leastprofitable = df3["Net_gain"]

# %%
leastprofitableplot = leastprofitable.plot(kind="bar")
